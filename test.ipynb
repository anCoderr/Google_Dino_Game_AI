# %%
from mss import mss
import pydirectinput
import cv2
import numpy as np
import pytesseract
from matplotlib import pyplot as plt
import time
from gym import Env
from gym.spaces import Box, Discrete

# %%
class WebGame(Env):
    def __init__(self):
        super().__init__()
        # Setup spaces
        self.observation_space = Box(low=0, high=255, shape=(1,83,100), dtype=np.uint8)
        self.action_space = Discrete(3)
        # Capture game frames
        self.cap = mss()
        self.game_location = {'top': 339 + 300, 'left': 2560 + 0, 'width': 600, 'height': 500}
        self.done_location = {'top': 405, 'left': 630, 'width': 660, 'height': 70}
        
        
    def step(self, action):
        action_map = {
            0:'space',
            1: 'down', 
            2: 'no_op'
        }
        if action !=2:
            pydirectinput.press(action_map[action])

        done, done_cap = self.get_done() 
        observation = self.get_observation()
        reward = 1 
        info = {}
        return observation, reward, done, info
        
    
    def reset(self):
        time.sleep(1)
        pydirectinput.click(x=150, y=150)
        pydirectinput.press('space')
        return self.get_observation()
        
    def render(self):
        cv2.imshow('Game', self.current_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            self.close()
         
    def close(self):
        cv2.destroyAllWindows()
    
    def get_observation(self):
        raw = np.array(self.cap.grab(self.game_location))[:,:,:3].astype(np.uint8)
        return raw
       
    
    def get_done(self):
        done_cap = np.array(self.cap.grab(self.done_location))
        done_strings = ['GAME', 'GAHE']
        done=False
        # if np.sum(done_cap) < 44300000:
        #     done = True
        done = False
        res = pytesseract.image_to_string(done_cap)[:4]
        if res in done_strings:
            done = True
        return done, done_cap

# %%
env = WebGame()

# %%
obs=env.get_observation()

# %%
plt.imshow(cv2.cvtColor(obs[0], cv2.COLOR_GRAY2BGR))

# %%
plt.imshow(env.get_observation())

# %%
import os 

from stable_baselines3.common.callbacks import BaseCallback

from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\AnCodeRR\Google_Dino_Game_AI\test.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/AnCodeRR/Google_Dino_Game_AI/test.ipynb#ch0000006?line=0'>1</a> env_checker.check_env(env)
#
# File c:\Users\deyol\.conda\envs\gpuPytorch\lib\site-packages\stable_baselines3\common\env_checker.py:283, in check_env(env, warn, skip_render_check)
#     278         warnings.warn(
#     279             f"Your action space has dtype {action_space.dtype}, we recommend using np.float32 to avoid cast errors."
#     280         )
#     282 # ============ Check the returned values ===============
# --> 283 _check_returned_values(env, observation_space, action_space)
#     285 # ==== Check the render method and the declared render modes ====
#     286 if not skip_render_check:
#
# File c:\Users\deyol\.conda\envs\gpuPytorch\lib\site-packages\stable_baselines3\common\env_checker.py:152, in _check_returned_values(env, observation_space, action_space)
#     150             raise AssertionError(f"Error while checking key={key}: " + str(e))
#     151 else:
# --> 152     _check_obs(obs, observation_space, "reset")
#     154 # Sample a random action
#     155 action = action_space.sample()
#
# File c:\Users\deyol\.conda\envs\gpuPytorch\lib\site-packages\stable_baselines3\common\env_checker.py:112, in _check_obs(obs, observation_space, method_name)
#     109 elif _is_numpy_array_space(observation_space):
#     110     assert isinstance(obs, np.ndarray), f"The observation returned by `{method_name}()` method must be a numpy array"
# --> 112 assert observation_space.contains(
#     113     obs
#     114 ), f"The observation returned by the `{method_name}()` method does not match the given observation space"
#
# AssertionError: The observation returned by the `reset()` method does not match the given observation space
